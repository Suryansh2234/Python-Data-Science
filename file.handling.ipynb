# %%
import os

# %%
print('Current Working Directory is:', os.getcwd())
# Out:
# Current Working Directory is: c:\Users\Acer\Desktop\Python with data science

# %%
files = os.listdir()
print('Files in Current working Directory', files)
# Out:
# Files in Current working Directory ['.git', 'abc.py', 'armstrong.py', 'assignment1.ipynb', 'basics.ipynb', 'conditions.ipynb', 'Data structure', 'fibonacci.py', 'file.handling.ipynb', 'FLASK', 'functions.ipynb', 'libraries.ipynb', 'loops.ipynb', 'operator.ipynb', 'pallindrome.py', 'patter2.py', 'pattern.py', 'prime.py', 'sets.ipynb', 'strings.ipynb']

# %%
files = os.listdir(r"C:\Users\Acer\Desktop\FoneTool")
print('Files in current working directory',files)
# Out:
# Files in current working directory ['mblibrary.db', 'mblibrary.db-shm', 'mblibrary.db-wal', 'Photos']

# %%
total_files = 0
for path, folders, files in os.walk(r"C:\Users\Acer\Desktop\Python with data science"):
    print('=>',path)
    print('📂', folders)
    print('🗃️', files)
    total_files += len(files)
print('Total files in directory tree:', total_files)
# Out:
# => C:\Users\Acer\Desktop\Python with data science
# 📂 ['.git', 'Data structure', 'FLASK']
# 🗃️ ['abc.py', 'armstrong.py', 'assignment1.ipynb', 'basics.ipynb', 'conditions.ipynb', 'fibonacci.py', 'file.handling.ipynb', 'functions.ipynb', 'libraries.ipynb', 'loops.ipynb', 'operator.ipynb', 'pallindrome.py', 'patter2.py', 'pattern.py', 'prime.py', 'sets.ipynb', 'strings.ipynb']
# => C:\Users\Acer\Desktop\Python with data science\.git
# 📂 ['hooks', 'info', 'logs', 'objects', 'refs']
# 🗃️ ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index']
# => C:\Users\Acer\Desktop\Python with data science\.git\hooks
# 📂 []
# 🗃️ ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# ...

# %%
files = r'assignment1.ipynb'
if os.path.exists(files):
    print('File exists')
else:
    print("File not exists")
# Out:
# File exists
